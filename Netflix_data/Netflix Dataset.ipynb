# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import os 
import json
import requests

# %%
# Load the data
netflix_data_csv = Path("../csv_folder/Netflix_data.csv")

# Load the data into a DataFrame
netflix_df = pd.read_csv(netflix_data_csv)

# Rename columns 
netflix_df = netflix_df.rename(columns={'title':'Title', 'type':'Type', 'genres':'Genres', 'releaseYear':'Release Year', 
                                    'imdbId':'IMDB ID', 'imdbAverageRating':'IMDB Average Rating', 
                                    'imdbNumVotes':'IMDB Votes', 'availableCountries':'Available Countries'})
netflix_df
# Out:
#                                        Title   Type  \
# 0                          The Fifth Element  movie
# 1                          Kill Bill: Vol. 1  movie
# 2                                    Jarhead  movie
# 3                                 Unforgiven  movie
# 4      Eternal Sunshine of the Spotless Mind  movie
# ...                                      ...    ...
# 20596                                    NaN     tv
# 20597                       Hidden Inventory     tv
# 20598                                    NaN     tv
# 20599                                    NaN     tv
# 20600                                    NaN     tv
#
#                              Genres  Release Year     IMDB ID  \
# 0         Action, Adventure, Sci-Fi        1997.0   tt0119116
# 1           Action, Crime, Thriller        2003.0   tt0266697
# 2             Biography, Drama, War        2005.0   tt0418763
# 3                    Drama, Western        1992.0   tt0105695
# 4            Drama, Romance, Sci-Fi        2004.0   tt0338013
# ...                             ...           ...         ...
# 20596                     Animation        2014.0         NaN
# 20597  Action, Adventure, Animation        2023.0  tt21361588
# 20598                           NaN           NaN         NaN
# 20599            Action & Adventure        2019.0         NaN
# 20600                           NaN        2014.0         NaN
#
#        IMDB Average Rating  IMDB Votes  \
# 0                      7.6    520154.0
# 1                      8.2   1231202.0
# 2                      7.0    213096.0
# 3                      8.2    447439.0
# 4                      8.3   1116956.0
# ...                    ...         ...
# 20596                  NaN         NaN
# 20597                  8.0      6127.0
# 20598                  NaN         NaN
# 20599                  NaN         NaN
# 20600                  NaN         NaN
#
#                                      Available Countries
# 0                                             AT, CH, DE
# 1      AE, AL, AO, AT, AU, AZ, BG, BH, BY, CI, CM, CZ...
# 2      AD, AE, AG, AO, BH, BM, BS, BZ, CI, CM, CO, CR...
# 3      AU, BA, BG, CZ, HR, HU, MD, ME, MK, NZ, PL, RO...
# 4      AD, AE, AG, AL, AO, AR, AU, AZ, BA, BB, BE, BG...
# ...                                                  ...
# 20596                                                 JP
# 20597  AD, AL, AO, AR, AT, AU, BA, BG, BO, BR, CA, CH...
# 20598                                     CA, JP, KR, US
# 20599  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20600                                                 TW
#
# [20601 rows x 8 columns]

# %%
# Create a new DataFrame with the columns needed for the analysis. Drop columns. 
netflix_df = netflix_df[['Title', 'Type', 'Genres', 'Release Year', 'IMDB Average Rating', 'Available Countries']]

netflix_df['Release Year'] = netflix_df['Release Year'].astype(str)
netflix_df['Release Year'] = netflix_df['Release Year'].str.split('.').str[0]
netflix_df
# Out:
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_13224\3190619128.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_df['Release Year'] = netflix_df['Release Year'].astype(str)
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_13224\3190619128.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_df['Release Year'] = netflix_df['Release Year'].str.split('.').str[0]
#                                        Title   Type  \
# 0                          The Fifth Element  movie
# 1                          Kill Bill: Vol. 1  movie
# 2                                    Jarhead  movie
# 3                                 Unforgiven  movie
# 4      Eternal Sunshine of the Spotless Mind  movie
# ...                                      ...    ...
# 20596                                    NaN     tv
# 20597                       Hidden Inventory     tv
# 20598                                    NaN     tv
# 20599                                    NaN     tv
# 20600                                    NaN     tv
#
#                              Genres Release Year  IMDB Average Rating  \
# 0         Action, Adventure, Sci-Fi         1997                  7.6
# 1           Action, Crime, Thriller         2003                  8.2
# 2             Biography, Drama, War         2005                  7.0
# 3                    Drama, Western         1992                  8.2
# 4            Drama, Romance, Sci-Fi         2004                  8.3
# ...                             ...          ...                  ...
# 20596                     Animation         2014                  NaN
# 20597  Action, Adventure, Animation         2023                  8.0
# 20598                           NaN          nan                  NaN
# 20599            Action & Adventure         2019                  NaN
# 20600                           NaN         2014                  NaN
#
#                                      Available Countries
# 0                                             AT, CH, DE
# 1      AE, AL, AO, AT, AU, AZ, BG, BH, BY, CI, CM, CZ...
# 2      AD, AE, AG, AO, BH, BM, BS, BZ, CI, CM, CO, CR...
# 3      AU, BA, BG, CZ, HR, HU, MD, ME, MK, NZ, PL, RO...
# 4      AD, AE, AG, AL, AO, AR, AU, AZ, BA, BB, BE, BG...
# ...                                                  ...
# 20596                                                 JP
# 20597  AD, AL, AO, AR, AT, AU, BA, BG, BO, BR, CA, CH...
# 20598                                     CA, JP, KR, US
# 20599  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20600                                                 TW
#
# [20601 rows x 6 columns]

# %%
# save as new csv file
netflix_df.to_csv("../Netflix_data/Netflix_data_cleaned.csv", index=False)

# %%
# Check for NaN values
print("NaN count per column:")
print(netflix_df.isnull().sum())

# Get rows with NaN
rows_with_nan = netflix_df[netflix_df.isnull().any(axis=1)]
print("\nRows with NaN values:")
print(rows_with_nan)
# Out:
# NaN count per column:
# Title                   616
# Type                      0
# Genres                  331
# Release Year              0
# IMDB Average Rating    1661
# Available Countries       0
# dtype: int64
#
# Rows with NaN values:
#                                                    Title   Type  \
# 2208                           Go! Anpanman: Ruby's Wish  movie
# 2404                                        Thunder Monk  movie
# 2508                               Breathe without Water  movie
# 2520                                El Arte De La Guerra  movie
# 2542   I Love You, East Garrison (A Video Essay by Ha...  movie
# ...                                                  ...    ...
# 20595                                                NaN     tv
# 20596                                                NaN     tv
# 20598                                                NaN     tv
# 20599                                                NaN     tv
# 20600                                                NaN     tv
#
#                              Genres Release Year  IMDB Average Rating  \
# 2208   Adventure, Animation, Family         2003                  NaN
# 2404                 Action, Comedy         2023                  NaN
# 2508                            NaN         2024                  NaN
# 2520                            NaN         2024                  NaN
# 2542            Comedy, Documentary         2023                  NaN
# ...                             ...          ...                  ...
# 20595                           NaN         2022                  NaN
# 20596                     Animation         2014                  NaN
# 20598                           NaN          nan                  NaN
# 20599            Action & Adventure         2019                  NaN
# 20600                           NaN         2014                  NaN
#
#                                      Available Countries
# 2208                                                  JP
# 2404                                                  TH
# 2508                                              CA, TH
# 2520                                                  KR
# 2542   AE, AL, AO, AT, AZ, BG, BH, BY, CI, CM, CZ, DE...
# ...                                                  ...
# 20595                                             PH, SG
# 20596                                                 JP
# 20598                                     CA, JP, KR, US
# 20599  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20600                                                 TW
#
# [1661 rows x 6 columns]

# %%
#netflix_df_cleaned = netflix_df.fillna("Unknown") 

#drop the nan values to clean data
netflix_df_dropna = netflix_df.dropna()
netflix_df_dropna
# Out:
#                                        Title   Type  \
# 0                          The Fifth Element  movie
# 1                          Kill Bill: Vol. 1  movie
# 2                                    Jarhead  movie
# 3                                 Unforgiven  movie
# 4      Eternal Sunshine of the Spotless Mind  movie
# ...                                      ...    ...
# 20573                         UniverXO Dabiz     tv
# 20576      Das Boot - Die komplette TV-Serie     tv
# 20581                       The Breakthrough     tv
# 20587                            Seven Doors     tv
# 20597                       Hidden Inventory     tv
#
#                              Genres Release Year  IMDB Average Rating  \
# 0         Action, Adventure, Sci-Fi         1997                  7.6
# 1           Action, Crime, Thriller         2003                  8.2
# 2             Biography, Drama, War         2005                  7.0
# 3                    Drama, Western         1992                  8.2
# 4            Drama, Romance, Sci-Fi         2004                  8.3
# ...                             ...          ...                  ...
# 20573                   Documentary         2024                  5.8
# 20576                    Drama, War         1985                  8.8
# 20581         Crime, Drama, Mystery         2025                  7.3
# 20587                         Drama         2024                  8.8
# 20597  Action, Adventure, Animation         2023                  8.0
#
#                                      Available Countries
# 0                                             AT, CH, DE
# 1      AE, AL, AO, AT, AU, AZ, BG, BH, BY, CI, CM, CZ...
# 2      AD, AE, AG, AO, BH, BM, BS, BZ, CI, CM, CO, CR...
# 3      AU, BA, BG, CZ, HR, HU, MD, ME, MK, NZ, PL, RO...
# 4      AD, AE, AG, AL, AO, AR, AU, AZ, BA, BB, BE, BG...
# ...                                                  ...
# 20573  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20576                                     AT, CH, DE, LI
# 20581  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20587  AO, CI, CM, CV, DZ, GH, GQ, KE, LY, MA, MG, ML...
# 20597  AD, AL, AO, AR, AT, AU, BA, BG, BO, BR, CA, CH...
#
# [18940 rows x 6 columns]

# %%
netflix_df_dropna = netflix_df_dropna[['Title', 'Type', 'Genres', 'Release Year', 'IMDB Average Rating', 'Available Countries']]

netflix_df_dropna['Release Year'] = netflix_df_dropna['Release Year'].astype(str)
netflix_df_dropna['Release Year'] = netflix_df_dropna['Release Year'].str.split('.').str[0]

netflix_df_dropna
# Out:
#                                        Title   Type  \
# 0                          The Fifth Element  movie
# 1                          Kill Bill: Vol. 1  movie
# 2                                    Jarhead  movie
# 3                                 Unforgiven  movie
# 4      Eternal Sunshine of the Spotless Mind  movie
# ...                                      ...    ...
# 20573                         UniverXO Dabiz     tv
# 20576      Das Boot - Die komplette TV-Serie     tv
# 20581                       The Breakthrough     tv
# 20587                            Seven Doors     tv
# 20597                       Hidden Inventory     tv
#
#                              Genres Release Year  IMDB Average Rating  \
# 0         Action, Adventure, Sci-Fi         1997                  7.6
# 1           Action, Crime, Thriller         2003                  8.2
# 2             Biography, Drama, War         2005                  7.0
# 3                    Drama, Western         1992                  8.2
# 4            Drama, Romance, Sci-Fi         2004                  8.3
# ...                             ...          ...                  ...
# 20573                   Documentary         2024                  5.8
# 20576                    Drama, War         1985                  8.8
# 20581         Crime, Drama, Mystery         2025                  7.3
# 20587                         Drama         2024                  8.8
# 20597  Action, Adventure, Animation         2023                  8.0
#
#                                      Available Countries
# 0                                             AT, CH, DE
# 1      AE, AL, AO, AT, AU, AZ, BG, BH, BY, CI, CM, CZ...
# 2      AD, AE, AG, AO, BH, BM, BS, BZ, CI, CM, CO, CR...
# 3      AU, BA, BG, CZ, HR, HU, MD, ME, MK, NZ, PL, RO...
# 4      AD, AE, AG, AL, AO, AR, AU, AZ, BA, BB, BE, BG...
# ...                                                  ...
# 20573  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20576                                     AT, CH, DE, LI
# 20581  AD, AE, AG, AL, AO, AR, AT, AU, AZ, BA, BB, BE...
# 20587  AO, CI, CM, CV, DZ, GH, GQ, KE, LY, MA, MG, ML...
# 20597  AD, AL, AO, AR, AT, AU, BA, BG, BO, BR, CA, CH...
#
# [18940 rows x 6 columns]

# %%
# save as new csv file 
netflix_df_dropna.to_csv("../Netflix_data/Netflix_data_cleaned_dropna.csv", index=False)
