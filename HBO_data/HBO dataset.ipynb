# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import os 
import json
import requests

# %%
# Load the data
hbo_data_csv = Path("../csv_folder/HBO_data.csv")

# Load the data into a DataFrame
hbo_df = pd.read_csv(hbo_data_csv)

# Rename columns 
hbo_df = hbo_df.rename(columns={'title':'Title', 'type':'Type', 'genres':'Genres', 'releaseYear':'Release Year', 
                                    'imdbId':'IMDB ID', 'imdbAverageRating':'IMDB Average Rating', 
                                    'imdbNumVotes':'IMDB Votes', 'availableCountries':'Available Countries'})
hbo_df.head()
# Out:
#                                    Title   Type                     Genres  \
# 0                      The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                                Jarhead  movie      Biography, Drama, War
# 2                             Unforgiven  movie             Drama, Western
# 3  Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
# 4                  A History of Violence  movie       Action, Crime, Drama
#
#    Release Year    IMDB ID  IMDB Average Rating  IMDB Votes  \
# 0        1997.0  tt0119116                  7.6    519964.0
# 1        2005.0  tt0418763                  7.0    213029.0
# 2        1992.0  tt0105695                  8.2    447253.0
# 3        2004.0  tt0338013                  8.3   1116278.0
# 4        2005.0  tt0399146                  7.4    260655.0
#
#                                  Available Countries
# 0                                     DK, FI, NO, SE
# 1                         HK, ID, MY, PH, SG, TH, TW
# 2  AG, AR, BB, BE, BO, BR, BS, BZ, CL, CO, CR, DO...
# 3  AG, AR, BB, BO, BS, BZ, CL, CO, CR, DO, EC, GT...
# 4  AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, EC...

# %%
# Create a new DataFrame with the columns needed for the analysis. Drop columns. 
hbo_df = hbo_df[['Title', 'Type', 'Genres', 'Release Year', 'IMDB Average Rating', 'Available Countries']]

# Convert 'Release Year' to only the year and remove the decimal
hbo_df['Release Year'] = hbo_df['Release Year'].astype(str)
hbo_df['Release Year'] = hbo_df['Release Year'].str.split('.').str[0]
hbo_df.head()
# Out:
#                                    Title   Type                     Genres  \
# 0                      The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                                Jarhead  movie      Biography, Drama, War
# 2                             Unforgiven  movie             Drama, Western
# 3  Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
# 4                  A History of Violence  movie       Action, Crime, Drama
#
#   Release Year  IMDB Average Rating  \
# 0         1997                  7.6
# 1         2005                  7.0
# 2         1992                  8.2
# 3         2004                  8.3
# 4         2005                  7.4
#
#                                  Available Countries
# 0                                     DK, FI, NO, SE
# 1                         HK, ID, MY, PH, SG, TH, TW
# 2  AG, AR, BB, BE, BO, BR, BS, BZ, CL, CO, CR, DO...
# 3  AG, AR, BB, BO, BS, BZ, CL, CO, CR, DO, EC, GT...
# 4  AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, EC...

# %%
# Check for NaN values
print("NaN count per column:")
print(hbo_df.isnull().sum())

# Get rows with NaN
rows_with_nan = hbo_df[hbo_df.isnull().any(axis=1)]
print("\nRows with NaN values:")
print(rows_with_nan)
# Out:
# NaN count per column:
# Title                  605
# Type                     0
# Genres                 285
# Release Year             0
# IMDB Average Rating    939
# Available Countries      0
# dtype: int64
#
# Rows with NaN values:
#                                     Title   Type                Genres  \
# 1483                          Siste trikk  movie                   NaN
# 1531                Breathe without Water  movie                   NaN
# 1595                                    X  movie      Thriller, Horror
# 2455                    Bita e os Animais  movie             Animation
# 2462              Hello Ladies: The Movie  movie      Comedy, TV Movie
# ...                                   ...    ...                   ...
# 9419                                  NaN     tv                 Crime
# 9421                                  NaN     tv           Documentary
# 9422                                  NaN     tv                   NaN
# 9423  Tony Robinson's Marvellous Machines     tv           Documentary
# 9427                                  NaN     tv  Reality, Documentary
#
#      Release Year  IMDB Average Rating  \
# 1483         2024                  NaN
# 1531         2024                  NaN
# 1595         2024                  NaN
# 2455         2014                  NaN
# 2462         2014                  NaN
# ...           ...                  ...
# 9419         2013                  NaN
# 9421         2021                  NaN
# 9422         2019                  NaN
# 9423         2023                  NaN
# 9427         2018                  NaN
#
#                                     Available Countries
# 1483                         AG, BB, BS, HN, NI, TT, US
# 1531                                                 US
# 1595                     BA, HR, MD, ME, MK, SI, SK, US
# 2455                                                 BR
# 2462  AD, AG, AR, BA, BB, BE, BG, BO, BR, BS, BZ, CL...
# ...                                                 ...
# 9419  BE, FR, HK, ID, MC, MY, NO, PH, PT, SG, TH, TW...
# 9421                                                 DK
# 9422  AD, BA, BE, BG, CZ, DK, ES, FI, FR, HR, HU, MC...
# 9423                                                 NL
# 9427  AD, AG, AR, BA, BB, BE, BG, BO, BR, BS, BZ, CL...
#
# [950 rows x 6 columns]

# %%
#drop the nan values to clean data
hbo_df_dropna = hbo_df.dropna()
hbo_df_dropna.head()
# Out:
#                                    Title   Type                     Genres  \
# 0                      The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                                Jarhead  movie      Biography, Drama, War
# 2                             Unforgiven  movie             Drama, Western
# 3  Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
# 4                  A History of Violence  movie       Action, Crime, Drama
#
#   Release Year  IMDB Average Rating  \
# 0         1997                  7.6
# 1         2005                  7.0
# 2         1992                  8.2
# 3         2004                  8.3
# 4         2005                  7.4
#
#                                  Available Countries
# 0                                     DK, FI, NO, SE
# 1                         HK, ID, MY, PH, SG, TH, TW
# 2  AG, AR, BB, BE, BO, BR, BS, BZ, CL, CO, CR, DO...
# 3  AG, AR, BB, BO, BS, BZ, CL, CO, CR, DO, EC, GT...
# 4  AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, EC...

# %%
hbo_df_dropna = hbo_df_dropna[['Title', 'Type', 'Genres', 'Release Year', 'IMDB Average Rating', 'Available Countries']]

hbo_df_dropna['Release Year'] = hbo_df_dropna['Release Year'].astype(str)
hbo_df_dropna['Release Year'] = hbo_df_dropna['Release Year'].str.split('.').str[0]

hbo_df_dropna.head()
# Out:
#                                    Title   Type                     Genres  \
# 0                      The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                                Jarhead  movie      Biography, Drama, War
# 2                             Unforgiven  movie             Drama, Western
# 3  Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
# 4                  A History of Violence  movie       Action, Crime, Drama
#
#   Release Year  IMDB Average Rating  \
# 0         1997                  7.6
# 1         2005                  7.0
# 2         1992                  8.2
# 3         2004                  8.3
# 4         2005                  7.4
#
#                                  Available Countries
# 0                                     DK, FI, NO, SE
# 1                         HK, ID, MY, PH, SG, TH, TW
# 2  AG, AR, BB, BE, BO, BR, BS, BZ, CL, CO, CR, DO...
# 3  AG, AR, BB, BO, BS, BZ, CL, CO, CR, DO, EC, GT...
# 4  AG, AR, BB, BO, BR, BS, BZ, CL, CO, CR, DO, EC...

# %%
# Save this as a new csv file
hbo_df.to_csv("../hbo_data/hbo_cleaned.csv", index=False)
